# %% [markdown]
# <a href="https://colab.research.google.com/github/knitinsingh/Lesson-1--Image-classification/blob/master/Fast_AI_lesson_one_whats_your_pet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate
import fastai
from fastai import *

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True, force_download=False) -> pathlib.Path
#     Download `url` to `fname` if it doesn't exist, and un-tgz to folder `dest`.

# %%
path = untar_data(URLs.PETS); path
# Out:
# PosixPath('/root/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images')]

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_113.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Bengal_131.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_187.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Bengal_117.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/leonberger_103.jpg')]

# %%
#?get_image_files

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
data.show_batch(rows=3, figsize=(7,6))
